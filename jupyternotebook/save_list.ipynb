# %%
filename = "E:/IR-VIS_dataset/train_IR_clean_new.txt"

f = open(filename, 'r')
lines = f.readlines()
f.close()
all_id = set()
a = ''
for line in lines:
    a = line
    id = line.split('/')[8]
    all_id.add(id)
len(all_id)
# Out:
# 118

# %%
# filename = "E:/IR-VIS_dataset/train_clean_new82.txt"
filename = "E:/IR-VIS_dataset/testVIS_daguo_new82.txt"

f = open(filename, 'r')
lines = f.readlines()
f.close()
all_id = set()
a = ''
# out1 = open("E:/IR-VIS_dataset/train_clean_new82_trainval_probe.txt", 'w')
out1 = open("E:/IR-VIS_dataset/testVIS_daguo_new82_probe.txt", 'w')
# out2 = open("E:/IR-VIS_dataset/train_clean_new82_trainval_gallery.txt", 'w')
out2 = open("E:/IR-VIS_dataset/testVIS_daguo_new82_gallery.txt", 'w')
flag = 1
for line in lines:
    if(flag):
        out1.write(line)
        flag = 1 - flag
    else:
        out2.write(line)
        flag = 1 - flag
out1.close()
out2.close()

# %%
filename = "E:/IR-VIS_dataset/train_IR_clean_new.txt"

f = open(filename, 'r')
lines = f.readlines()
f.close()
all_id = set()
a = ''
for line in lines:
    a = line
    id = line.split('/')[8]
    all_id.add(id)
len(all_id)
# Out:
# 118

# %%
a.split(a.split('/')[7])[1]
# Out:
# '/0126/4_p4_0_0_0_0_IR.jpg\n'

# %%
118-93  25
118+28  146
# Out:
#   File "<ipython-input-22-2e0d21e79dd7>", line 1
#     118-93  25
#              ^
# SyntaxError: invalid syntax

# %%
filename = "E:/IR-VIS_dataset/guoda_raw/all_IR_imgs.txt"

f = open(filename, 'r')
lines = f.readlines()
f.close()
all_id = set()
for line in lines:
    id = line.split('/')[4]
    all_id.add(id)
len(all_id)
# Out:
# 53

# %%
import os
import os.path
import natsort

# rootdir="/Users/dale/OneDrive/Data/cluster_select/IR_p"
# rootdir="/Users/dale/OneDrive/Data/cluster_select/VIS"

# rootdir="/Users/dale/OneDrive/Data/cluster_select/test/IR_p"
rootdir="/Users/dale/OneDrive/Data/cluster_select/test/VIS"

# savefile="/Users/dale/OneDrive/Data/cluster_select/test/all_IR_p_npy.txt"
# savefile="/Users/dale/OneDrive/Data/cluster_select/test/all_IR_p_npy_resnet10.txt"
savefile="/Users/dale/OneDrive/Data/cluster_select/test/all_VIS_npy.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'npy' and len(filename.strip().split('.')) == 2: #IR
#         if filename.strip().split('.')[-1] == 'npy' and len(filename.strip().split('.')) == 2: #IR
#         if filename.strip().split('.')[-1] == 'npy' and len(filename.strip().split('.')) == 3: #IR
#         if filename.strip().split('.')[-1] == 'resnet10.npy': #IR
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="E:/IR-VIS_dataset/guoda_raw/Images_noAttribute_res2"
savefile="E:/IR-VIS_dataset/guoda_raw/all_IR_imgs.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('_')[-1] == 'IR.jpg': #IR
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

# rootdir="D:/sm/data/detect3-1"
rootdir="D:/sm/data/detect3-1_json/detect3-1"
# savefile="D:/sm/data/detect3-1/all_imgs.txt"
savefile="D:/sm/data/detect3-1_json/detect3-1/all_json.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
#         if filename.strip().split('.')[-1] == 'bmp':
        if filename.strip().split('.')[-1] == 'json':
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

# rootdir="/Users/dale/Downloads/tdface.ece.tufts.edu/downloads/TD_IR_RGB_CROPPED/RGB-faces-128x128"
# rootdir="/Users/dale/Downloads/tdface.ece.tufts.edu/downloads/TD_IR_RGB_CROPPED_112/thermal-face"
rootdir="/Users/dale/TD_IR_RGB_CROPPED_128_DVG_result/thermal-face-128x128"
# savefile="/Users/dale/Downloads/tdface.ece.tufts.edu/downloads/TD_IR_RGB_CROPPED/all_VIS_imgs.txt"
# savefile="/Users/dale/Downloads/tdface.ece.tufts.edu/downloads/TD_IR_RGB_CROPPED_112/all_IR_imgs.txt"
savefile="/Users/dale/TD_IR_RGB_CROPPED_128_DVG_result/thermal-face-128x128/all_IR_imgs.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[1] == 'jpg': 
#         if filename.strip().split('_')[-1] == 'IR.jpg': #IR
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="C:/Users/HP/Desktop/深度学习/balls_data_png"
savefile="C:/Users/HP/Desktop/深度学习/balls_data_png/all_imgs.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'png': #IR
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="H:/BaiduNetdiskDownload/1000红外人像"
savefile="H:/BaiduNetdiskDownload/1000红外人像/all_vis_list.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('-')[-1] == '7': #IR
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

# rootdir="H:/BaiduNetdiskDownload/1000红外人像/20210423"
# rootdir="H:/BaiduNetdiskDownload/1000红外人像/20210518"
rootdir="H:/BaiduNetdiskDownload/1000红外人像/20210523"
# savefile="H:/BaiduNetdiskDownload/1000红外人像/all_vis_list_20210423.txt"
# savefile="H:/BaiduNetdiskDownload/1000红外人像/all_vis_list_20210518.txt"
savefile="H:/BaiduNetdiskDownload/1000红外人像/all_vis_list_20210523.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('-')[-1] == '7': #IR
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
'''
for VIS video
'''
import os
import os.path
import natsort


rootdir="H:/BaiduNetdiskDownload/1000红外人像-vis"

savefile="H:/BaiduNetdiskDownload/1000红外人像-vis/all_vis_video_list.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
num_list = ['1', '2', '3', '4', '5', '6', '7', '8']
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        video_num = filename.strip().split('-')[-1]
        if video_num in num_list: 
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    sort_list[i] = sort_list[i].replace('\\', '/') 
    out.write(sort_list[i] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="H:/BaiduNetdiskDownload/all_IR_download_frontal"
savefile="H:/BaiduNetdiskDownload/all_IR_download_frontal/all_IR_frontal_list.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'bmp': #IR
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
            num_video = file_path.split('/')[5]
            if(num_video == '23'):
#                 print(file_path)
                imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="H:/BaiduNetdiskDownload/1000-dataset_image20210423"
savefile="H:\BaiduNetdiskDownload\1000-dataset_image20210423/all_IR_frontal_list-240-334.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'bmp': #IR
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
            num_video = file_path.split('/')[5]
            if(num_video == '23'):
#                 print(file_path)
                imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="H:/BaiduNetdiskDownload/all_IR_download_frontal/547-600"
savefile="H:/BaiduNetdiskDownload/all_IR_download_frontal/all_IP_p_frontal_list-547-600.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'bmp': #IR
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
            num_video = file_path.split('/')[5]
            if(num_video == '23'):
#                 print(file_path)
                imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="H:/BaiduNetdiskDownload/VIS-frontal-images-download"
savefile="H:/BaiduNetdiskDownload/VIS-frontal-images-download/all_VIS_frontal_list-600.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'jpg': #VIS
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
            num_video = file_path.split('/')[5]
            if(num_video == '7'):
#                 print(file_path)
                imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="H:/BaiduNetdiskDownload/VIS-frontal-images-download_7"
savefile="H:/BaiduNetdiskDownload/VIS-frontal-images-download_7/all_VIS_frontal_list-241-600.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'jpg': #VIS
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
#             num_video = file_path.split('/')[5]
#             if(num_video == '7'):
#                 print(file_path)
            imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_23_frontal_images"
savefile="H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_23_frontal_images/all_IR_p_frontal_list.txt"
out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'bmp': #IR
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
#             num_video = file_path.split('/')[5]
#             if(num_video == '7'):
#                 print(file_path)
            imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

# rootdir="H:/BaiduNetdiskDownload/face_SIAT/IR_p"
# rootdir="H:/BaiduNetdiskDownload/face_SIAT/VIS"

rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/IR_p"
rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/VIS"


# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_IR_p_faces.txt"
# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_VIS_faces.txt"

savefile="H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/all_VIS_faces.txt"


out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
#         if filename.strip().split('.')[-1] == 'bmp': #IR
        if filename.strip().split('.')[-1] == 'jpg': #VIS
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

# rootdir="/Users/dale/Downloads/dataset_0127/IR_p"
# rootdir="/Users/dale/Downloads/dataset_0127/IR"
# rootdir="/Users/dale/Downloads/dataset_0127/VIS_images"
rootdir="/Users/dale/Downloads/dataset_0127/IR_p_images"
# savefile="/Users/dale/Downloads/dataset_0127/IR_p/raw_list.txt"
# savefile="/Users/dale/Downloads/dataset_0127/IR/raw_list.txt"
# savefile="/Users/dale/Downloads/dataset_0127/VIS_images/VIS_images_list.txt"
savefile="/Users/dale/Downloads/dataset_0127/IR_p_images/IR_p_images_list.txt"

out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[1] == 'bmp': 
#         if filename.strip().split('.')[1] == 'jpg': 
#         if filename.strip().split('.')[1] == 'raw': 
#         if filename.strip().split('_')[-1] == 'IR.jpg': #IR
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

rootdir="/Users/dale/Downloads/dataset_0127/VIS"
savefile="/Users/dale/Downloads/dataset_0127/VIS_avi_list.txt"

out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[1] == 'avi': 
#         if filename.strip().split('_')[-1] == 'IR.jpg': #IR
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
file_name = "D:/sm/data/detect3-1_json/detect3-1/all_json.txt"
save_dir = "D:/sm/data/detect3-1_all_json/detect3-1"
        
if not os.path.exists(save_dir):
    os.makedirs(save_dir)


import os

with open(file_name, 'r') as f:
    lines = f.readlines()
    for line in lines:
        source_path = line.strip()
        target_path = source_path.replace("detect3-1_json", "detect3-1_all_json")        
        file_name = target_path.split('/')[-1]
        target_path = target_path.split(str('/'+file_name))[0] + '_' + file_name
        os.system("copy {0} {1}".format(source_path, target_path))
        print("copy {0} {1}".format(source_path, target_path))
#         print(target_path)
# Out:
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_55_35/1.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_55_35_1.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_55_35/2.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_55_35_2.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_55_35/3.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_55_35_3.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_55_35/4.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_55_35_4.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_58_19/1.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_58_19_1.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_58_19/2.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_58_19_2.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_58_19/3.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_58_19_3.json
# ...

# %%
file_name = "D:/sm/data/detect3-1_json/detect3-1/all_json.txt"
save_dir = "D:/sm/data/detect3-1_all_json/detect3-1"
        
if not os.path.exists(save_dir):
    os.makedirs(save_dir)


import os

with open(file_name, 'r') as f:
    lines = f.readlines()
    for line in lines:
        source_path = line.strip()
        target_path = source_path.replace("detect3-1_json", "detect3-1_all_json")        
        file_name = target_path.split('/')[-1]
        target_path = target_path.split(str('/'+file_name))[0] + '_' + file_name
        os.system("copy {0} {1}".format(source_path, target_path))
        print("copy {0} {1}".format(source_path, target_path))
#         print(target_path)
# Out:
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_55_35/1.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_55_35_1.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_55_35/2.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_55_35_2.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_55_35/3.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_55_35_3.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_55_35/4.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_55_35_4.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_58_19/1.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_58_19_1.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_58_19/2.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_58_19_2.json
# copy D:/sm/data/detect3-1_json/detect3-1/2021_03_01_10_58_19/3.json D:/sm/data/detect3-1_all_json/detect3-1/2021_03_01_10_58_19_3.json
# ...

# %%
import os
file_name = "H:/BaiduNetdiskDownload/all_IR_download_frontal/all_IR_frontal_list-3.txt"
save_dir = "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_23_frontal/"

# savefile="H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_23_frontal/copycmd.txt"
# out = open(savefile,'w')

# if not os.path.exists(save_dir):
#     os.makedirs(save_dir)

# import os

with open(file_name, 'r') as f:
    lines = f.readlines()
    for line in lines:
        source_path = line.strip()
        save_id = source_path.split('/')[4]
        save_name = source_path.split('/')[-1]
#         target_path = source_path.replace("all_IR_download_frontal/240-frontal", "1000-dataset_images/IR_p_23_frontal").split(save_id)[0]  + str(int(save_id)) + "/" + save_name  
#         target_path = source_path.replace("all_IR_download_frontal/frontal-20210518", "1000-dataset_images/IR_p_23_frontal").split(save_id)[0]  + str(int(save_id)) + "/" + save_name  
        target_path = source_path.replace("all_IR_download_frontal/frontal-20210523", "1000-dataset_images/IR_p_23_frontal").split(save_id)[0]  + str(int(save_id)) + "/" + save_name  
        target_dir = os.path.dirname(target_path)
        if not os.path.exists(target_dir):
            os.makedirs(target_dir)
        source_path = source_path.replace('/', '\\') 
        target_dir = target_dir.replace('/', '\\') 
        os.system("copy {0} {1}".format(source_path, target_dir))
        print("copy {0} {1}".format(source_path, target_dir))
#         out.write("copy {0} {1}\n\n".format(source_path, target_dir))
#         print(target_path)
# out.close()
# Out:
# copy H:\BaiduNetdiskDownload\all_IR_download_frontal\frontal-20210523\434\23\434-230072.bmp H:\BaiduNetdiskDownload\1000-dataset_images\IR_p_23_frontal\434
# copy H:\BaiduNetdiskDownload\all_IR_download_frontal\frontal-20210523\434\23\434-230073.bmp H:\BaiduNetdiskDownload\1000-dataset_images\IR_p_23_frontal\434
# copy H:\BaiduNetdiskDownload\all_IR_download_frontal\frontal-20210523\434\23\434-230074.bmp H:\BaiduNetdiskDownload\1000-dataset_images\IR_p_23_frontal\434
# copy H:\BaiduNetdiskDownload\all_IR_download_frontal\frontal-20210523\434\23\434-230075.bmp H:\BaiduNetdiskDownload\1000-dataset_images\IR_p_23_frontal\434
# copy H:\BaiduNetdiskDownload\all_IR_download_frontal\frontal-20210523\434\23\434-230076.bmp H:\BaiduNetdiskDownload\1000-dataset_images\IR_p_23_frontal\434
# copy H:\BaiduNetdiskDownload\all_IR_download_frontal\frontal-20210523\434\23\434-230077.bmp H:\BaiduNetdiskDownload\1000-dataset_images\IR_p_23_frontal\434
# ...

# %%
import os
import os.path
import natsort


#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/IR_p"
#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/VIS"
rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256"

# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_IR_p_faces.txt"
# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_VIS_faces.txt"

savefile="H:/BaiduNetdiskDownload/1000-dataset_images/All_IR_faces_frontal_501"


out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
         if filename.strip().split('.')[-1] == 'bmp': #IR
        #if filename.strip().split('.')[-1] == 'jpg': #VIS
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort


#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/IR_p"
#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/VIS"
rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256"

# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_IR_p_faces.txt"
# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_VIS_faces.txt"

savefile="H:/BaiduNetdiskDownload/1000-dataset_images/All_VIS_faces_frontal_501"


out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        # if filename.strip().split('.')[-1] == 'bmp': #IR
        if filename.strip().split('.')[-1] == 'jpg': #VIS
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

#rootdir="H:/BaiduNetdiskDownload/all_IR_download_frontal/547-600"
#savefile="H:/BaiduNetdiskDownload/all_IR_download_frontal/all_IP_p_frontal_list-547-600.txt"
rootdir= "I:/1-600红外人像/image"
savefile= "I:/1-600红外人像/image/241_334_IR_frontal.txt"
out = open(savefile,'w')
#data = [241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334
#]
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    
    #if dirnames in data:
        #print(dirnames)
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'bmp': #IR
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
            num_video = file_path.split('/')[4]
            if(num_video == '23'):
#                 print(file_path)
                imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort


#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/IR_p"
#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/VIS"
#rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256"
rootdir= "H:/241_336_process/IR_P_image_23"

# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_IR_p_faces.txt"
# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_VIS_faces.txt"

savefile="H:/241_336_process/IR_P_image_23/all_IR_p_frontal_241_334.txt"


out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'bmp': #IR
        #if filename.strip().split('.')[-1] == 'jpg': #VIS
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

#rootdir="H:/BaiduNetdiskDownload/all_IR_download_frontal/547-600"
#savefile="H:/BaiduNetdiskDownload/all_IR_download_frontal/all_IP_p_frontal_list-547-600.txt"
#rootdir= "I:/1-600红外人像/image"
#savefile= "I:/1-600红外人像/image/241_334_IR_frontal.txt"
rootdir= "I:/renxiangcaiji/IR_601-1000/frontal_IR"
savefile= "I:/renxiangcaiji/IR_601-1000/frontal_IR/601_1000_IR_frontal.txt"

out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'bmp': #IR
        #if filename.strip().split('.')[-1] == 'jpg': #VIS
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
            num_video = file_path.split('/')[5]
            if(num_video == '23'):
            #if(num_video == '7'):
#                 print(file_path)
                imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort


#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/IR_p"
#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/VIS"
#rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256"
rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256"
#rootdir= "H:/241_336_process/VIS_image_600-1000"
#rootdir= "H:/241_336_process/VIS_p_frontal_241-334"

# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_IR_p_faces.txt"
# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_VIS_faces.txt"

#savefile="H:/241_336_process/VIS_p_frontal_241-334/all_VIS_frontal_241_334.txt"
#savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256/all_IR_p_frontal_241_1000.txt"
savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256/all_VIS_frontal_241_1000.txt"

out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        #f filename.strip().split('.')[-1] == 'bmp': #IR
        if filename.strip().split('.')[-1] == 'jpg': #VIS
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort


#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/IR_p"
#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/VIS"
#rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256"
# rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256"
rootdir = "H:/BaiduNetdiskDownload/VIS-frontal-images-download_7_241-600"
#rootdir= "H:/241_336_process/VIS_image_600-1000"
#rootdir= "H:/241_336_process/VIS_p_frontal_241-334"

# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_IR_p_faces.txt"
# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_VIS_faces.txt"

#savefile="H:/241_336_process/VIS_p_frontal_241-334/all_VIS_frontal_241_334.txt"
#savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256/all_IR_p_frontal_241_1000.txt"
# savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256/all_VIS_frontal_241_1000.txt"
savefile = "H:/BaiduNetdiskDownload/VIS-frontal-images-download_7_241-600/all_VIS_frontal_list-241-600.txt"

out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
#         f filename.strip().split('.')[-1] == 'bmp': #IR
        if filename.strip().split('.')[-1] == 'jpg': #VIS
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort


#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/IR_p"
#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/VIS"
#rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256"
# rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256"
# rootdir = "H:/BaiduNetdiskDownload/VIS-frontal-images-download_7_241-600"
#rootdir= "H:/241_336_process/VIS_image_600-1000"
#rootdir= "H:/241_336_process/VIS_p_frontal_241-334"
rootdir = "F:/远距离红外人像采集/视频转图片/可见光"

# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_IR_p_faces.txt"
# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_VIS_faces.txt"

#savefile="H:/241_336_process/VIS_p_frontal_241-334/all_VIS_frontal_241_334.txt"
#savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256/all_IR_p_frontal_241_1000.txt"
# savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256/all_VIS_frontal_241_1000.txt"
# savefile = "H:/BaiduNetdiskDownload/VIS-frontal-images-download_7_241-600/all_VIS_frontal_list-241-600.txt"
savefile = "F:/远距离红外人像采集/视频转图片/可见光/yuanju_VIS_image.txt"

out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
#         f filename.strip().split('.')[-1] == 'bmp': #IR
        if filename.strip().split('.')[-1] == 'jpg': #VIS
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

#rootdir="H:/BaiduNetdiskDownload/all_IR_download_frontal/547-600"
#savefile="H:/BaiduNetdiskDownload/all_IR_download_frontal/all_IP_p_frontal_list-547-600.txt"
#rootdir= "I:/1-600红外人像/image"
#savefile= "I:/1-600红外人像/image/241_334_IR_frontal.txt"
# rootdir= "I:/renxiangcaiji/IR_601-1000/frontal_IR"
# savefile= "I:/renxiangcaiji/IR_601-1000/frontal_IR/601_1000_IR_frontal.txt"
rootdir = "F:/远距离红外人像采集/视频转图片"
savefile = "F:/远距离红外人像采集/视频转图片/yuanju_IR_p_50_image.txt"


out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    
    for filename in filenames:
#         print(filename)
#         if filename.strip().split('.')[-1] == 'bmp': #IR
        if filename.strip().split('.')[-1] == 'jpg': #VIS
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
            num_video = file_path.split('/')[4]
#             print(num_video)
#             if(num_video == '23'):
            if(num_video == '50m'):
            #if(num_video == '7'):
#                 print(file_path)
                imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort


#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/IR_p"
#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/VIS"
#rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256"
# rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256"
# rootdir = "H:/BaiduNetdiskDownload/VIS-frontal-images-download_7_241-600"
#rootdir= "H:/241_336_process/VIS_image_600-1000"
#rootdir= "H:/241_336_process/VIS_p_frontal_241-334"
rootdir = "F:/远距离红外人像采集/IR-100m"

# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_IR_p_faces.txt"
# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_VIS_faces.txt"

#savefile="H:/241_336_process/VIS_p_frontal_241-334/all_VIS_frontal_241_334.txt"
#savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256/all_IR_p_frontal_241_1000.txt"
# savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256/all_VIS_frontal_241_1000.txt"
# savefile = "H:/BaiduNetdiskDownload/VIS-frontal-images-download_7_241-600/all_VIS_frontal_list-241-600.txt"
savefile = "F:/远距离红外人像采集/IR-100m/IR_100m_image.txt"

out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
#         f filename.strip().split('.')[-1] == 'bmp': #IR
        if filename.strip().split('.')[-1] == 'jpg': #VIS
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort

#rootdir="H:/BaiduNetdiskDownload/all_IR_download_frontal/547-600"
#savefile="H:/BaiduNetdiskDownload/all_IR_download_frontal/all_IP_p_frontal_list-547-600.txt"
#rootdir= "I:/1-600红外人像/image"
#savefile= "I:/1-600红外人像/image/241_334_IR_frontal.txt"
# rootdir= "I:/renxiangcaiji/IR_601-1000/frontal_IR"
# savefile= "I:/renxiangcaiji/IR_601-1000/frontal_IR/601_1000_IR_frontal.txt"
# rootdir = "F:/远距离红外人像采集/视频转图片"
# savefile = "F:/远距离红外人像采集/视频转图片/yuanju_IR_p_50_image.txt"
rootdir = "E:/乱"
savefile = "E:/乱/all_frontal.txt"


out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    
    for filename in filenames:
#         print(filename)
        if filename.strip().split('.')[-1] == 'bmp': #IR
#         if filename.strip().split('.')[-1] == 'jpg': #VIS
            file_path = str(os.path.join(parent,filename)).replace('\\', '/') 
#             num_video = file_path.split('/')[4]
#             num_video = file_path.split('/')[5]
#             print(num_video)
#             if(num_video == '23'):
#             if(num_video == '50m'):
            if('正脸' in file_path):
            #if(num_video == '7'):
#                 print(file_path)
                imglist.append(str(os.path.join(parent,filename)))
#             break
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
#     sort_list[i] = sort_list[i].replace('\\', '/') 
#     print(sort_list[i] )
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...

# %%
import os
import os.path
import natsort


#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/IR_p"
#rootdir= "H:/BaiduNetdiskDownload/face_SIAT/frontal-128-140/VIS"
#rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256"
# rootdir= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256"
# rootdir = "H:/BaiduNetdiskDownload/VIS-frontal-images-download_7_241-600"
#rootdir= "H:/241_336_process/VIS_image_600-1000"
#rootdir= "H:/241_336_process/VIS_p_frontal_241-334"
rootdir = "F:/1-400IR_p/FA"

# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_IR_p_faces.txt"
# savefile="H:/BaiduNetdiskDownload/face_SIAT/all_VIS_faces.txt"

#savefile="H:/241_336_process/VIS_p_frontal_241-334/all_VIS_frontal_241_334.txt"
#savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/IR_p_faces_frontal_256/all_IR_p_frontal_241_1000.txt"
# savefile= "H:/BaiduNetdiskDownload/1000-dataset_images/VIS_faces_frontal_256/all_VIS_frontal_241_1000.txt"
# savefile = "H:/BaiduNetdiskDownload/VIS-frontal-images-download_7_241-600/all_VIS_frontal_list-241-600.txt"
savefile = "F:/1-400IR_p/FA/all_frontal.txt"

out = open(savefile,'w')
imglist=[]
print ('start...')
for parent,dirnames,filenames in os.walk(rootdir):
    for filename in filenames:
        if filename.strip().split('.')[-1] == 'bmp': #IR
#         if filename.strip().split('.')[-1] == 'jpg': #VIS
        #if filename.strip().split('_')[-1] == 'VIS_jpg':  #VIS
            imglist.append(str(os.path.join(parent,filename)))
sort_list = natsort.natsorted(imglist)
for i in range(len(sort_list)):
    #print(sort_list[int(i)])
    out.write(sort_list[i] + '\n') #+ ' ' + sort_list[i].split('/')[6] + '\n')
out.close()
print ('successful...')
# Out:
# start...
# successful...
